# %% [markdown]
# At times, a single model might be able to provide the expected/ satisfactory results. We might need to combine more than 1 model to get better results. This technique of combining more than one model is called ensembling of models.
# <pre>
# Ensembling models can be categorised into
# Bagging model - the combined models work parallely on parts of the training data, and their results are aggregated
# Boosting model - the combined models work sequentially on the entire data, subsequent models rectify the error of       previous models (multiple weeker models, chained to become a single strong model)
# </pre>

# %%
#importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Read data
# In this demo, we are going to work on spambase dataset, where the normalized frequency of different words in an email are recorded, based on which an email is labelled as spam (1) or not spam (0)

# %%
#reading input data from csv file
spam_data = pd.read_csv("datasets/spambase.csv")

# %% [markdown]
# #### Splitting the data into train and test set

# %%
from sklearn.model_selection import train_test_split
features = spam_data.columns.drop('spam')
target = "spam"
X=spam_data[features]
Y=spam_data[target]
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=100)

# %% [markdown]
# ### Bagging using Random Forest Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10,
                               min_samples_split=20,
                               min_impurity_decrease=0.05)
model.fit(X_train,Y_train)
train_accuracy = model.score(X_train,Y_train)
test_accuracy = model.score(X_test,Y_test)
print(train_accuracy,test_accuracy)
# Out:
# 0.8633152173913043 0.8577633007600435

# %% [markdown]
# #### Reviewing the feature importances

# %%
feature_imps = pd.DataFrame(np.array([features,
                                      model.feature_importances_]).T,
                            columns=["feature","importance"])
feature_imps.sort_values(by="importance",ascending=False)
# Out:
#                        feature importance
# 20              word_freq_your   0.213714
# 15              word_freq_free   0.200673
# 52                 char_freq_$   0.187872
# 51                 char_freq_!   0.139886
# 6             word_freq_remove   0.069712
# 22               word_freq_000  0.0551342
# 18               word_freq_you  0.0432799
# 23             word_freq_money  0.0322997
# 54  capital_run_length_average   0.029615
# 19            word_freq_credit  0.0278139
# 40                word_freq_cs          0
# 41           word_freq_meeting          0
# 0               word_freq_make          0
# 39            word_freq_direct          0
# 38                word_freq_pm          0
# 36              word_freq_1999          0
# 35        word_freq_technology          0
# 34                word_freq_85          0
# 37             word_freq_parts          0
# 43           word_freq_project          0
# 42          word_freq_original          0
# 32              word_freq_data          0
# 44                word_freq_re          0
# 45               word_freq_edu          0
# 46             word_freq_table          0
# 47        word_freq_conference          0
# 48                 char_freq_;          0
# 49                 char_freq_(          0
# 50                 char_freq_[          0
# 53                 char_freq_#          0
# 55  capital_run_length_longest          0
# 33               word_freq_415          0
# 28               word_freq_lab          0
# 31               word_freq_857          0
# 30            word_freq_telnet          0
# 2                word_freq_all          0
# 3                 word_freq_3d          0
# 4                 word_req_our          0
# 5               word_freq_over          0
# 7           word_freq_internet          0
# 8              word_freq_order          0
# 9               word_freq_mail          0
# 10           word_freq_receive          0
# 11              word_freq_will          0
# 12            word_freq_people          0
# 13            word_freq_report          0
# 14         word_freq_addresses          0
# 16          word_freq_business          0
# 17             word_freq_email          0
# 21              word_freq_font          0
# 24                word_freq_hp          0
# 25               word_freq_hpl          0
# 26            word_freq_george          0
# 27               word_freq_650          0
# 1            word_freq_address          0
# 29              word_freq_labs          0
# 56    capital_run_length_total          0

# %% [markdown]
# #### Optional Exercise: Tune the hyperparamters of the random forest classifier using KFold cross validation

# %% [markdown]
# ## Boosting using Adaboost Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
model = AdaBoostClassifier(n_estimators=10)
model.fit(X_train,Y_train)
train_accuracy = model.score(X_train,Y_train)
test_accuracy = model.score(X_test,Y_test)
print(train_accuracy,test_accuracy)
# Out:
# 0.9195652173913044 0.9272529858849077

# %% [markdown]
# #### Reviewing the feature importances

# %%
feature_imps = pd.DataFrame(np.array([features,
                                      model.feature_importances_]).T,
                            columns=["feature","importance"])
feature_imps.sort_values(by="importance",ascending=False)
# Out:
#                        feature importance
# 15              word_freq_free        0.1
# 45               word_freq_edu        0.1
# 55  capital_run_length_longest        0.1
# 52                 char_freq_$        0.1
# 6             word_freq_remove        0.1
# 51                 char_freq_!        0.1
# 26            word_freq_george        0.1
# 44                word_freq_re        0.1
# 24                word_freq_hp        0.1
# 36              word_freq_1999        0.1
# 39            word_freq_direct          0
# 38                word_freq_pm          0
# 35        word_freq_technology          0
# 37             word_freq_parts          0
# 41           word_freq_meeting          0
# 34                word_freq_85          0
# 33               word_freq_415          0
# 40                word_freq_cs          0
# 0               word_freq_make          0
# 42          word_freq_original          0
# 43           word_freq_project          0
# 31               word_freq_857          0
# 46             word_freq_table          0
# 47        word_freq_conference          0
# 48                 char_freq_;          0
# 49                 char_freq_(          0
# 50                 char_freq_[          0
# 53                 char_freq_#          0
# 54  capital_run_length_average          0
# 32              word_freq_data          0
# 28               word_freq_lab          0
# 30            word_freq_telnet          0
# 29              word_freq_labs          0
# 2                word_freq_all          0
# 3                 word_freq_3d          0
# 4                 word_req_our          0
# 5               word_freq_over          0
# 7           word_freq_internet          0
# 8              word_freq_order          0
# 9               word_freq_mail          0
# 10           word_freq_receive          0
# 11              word_freq_will          0
# 12            word_freq_people          0
# 13            word_freq_report          0
# 14         word_freq_addresses          0
# 16          word_freq_business          0
# 17             word_freq_email          0
# 18               word_freq_you          0
# 19            word_freq_credit          0
# 20              word_freq_your          0
# 21              word_freq_font          0
# 22               word_freq_000          0
# 23             word_freq_money          0
# 25               word_freq_hpl          0
# 27               word_freq_650          0
# 1            word_freq_address          0
# 56    capital_run_length_total          0

# %% [markdown]
# #### Optional Exercise: Tune the adaboost classifier using cross validation
